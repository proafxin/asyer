# %%
from os.path import (
    abspath,
    dirname,
    exists,
    join,
)
from pandas import (
    read_csv,
    merge,
    concat,
    DataFrame,
    Series,
)
from random import randint
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    mean_absolute_percentage_error,
    average_precision_score,
    f1_score,
)

# %%
PWD = (abspath(''))
datadir = join(PWD, '../Datasets/ml-1m/')
files = {}
files['train'] = join(datadir, 'train.csv')
files['test'] = join(datadir, 'test.csv')
THRESHOLD = 5
NEIGHBOR = 20
SIMILARITY = .7

# %%
dfs = {}
for file in files:
    dfs[file] = read_csv(
        files[file],
        engine='python',
        encoding='latin1',
    )
    dfs[file]['rating'] = dfs[file]['rating'].astype(int)

# %%
dfs['train'].head()
# Out:
#                title  rating  userId
# 0   Airplane! (1980)       4       1
# 1     Aladdin (1992)       4       1
# 2        Antz (1998)       4       1
# 3   Apollo 13 (1995)       5       1
# 4  Awakenings (1990)       5       1

# %%
ratings = {}
users = dfs['train']['userId'].to_numpy()
users = set(users)
users = list(users)
for user in users:
    ratings[user] = {}

# %%
rows = dfs['train'].to_numpy()
for row in rows:
    ratings[row[2]][row[0]] = row[1]

# %%
dfs['test'].head()
# Out:
#                                        title  rating  userId
# 0     Snow White and the Seven Dwarfs (1937)       4       1
# 1                 Sound of Music, The (1965)       5       1
# 2  Star Wars: Episode IV - A New Hope (1977)       4       1
# 3                              Tarzan (1999)       3       1
# 4                             Titanic (1997)       4       1

# %%
dfs['train'].shape, dfs['test'].shape
# Out:
# ((755865, 3), (99865, 3))

# %%
dfs['test'][dfs['test']['title'].isin(dfs['train']['title'])].shape
# Out:
# (99865, 3)

# %%
dfs['pivot'] = dfs['train'].pivot_table(
    index=['userId'],
    columns=['title'],
    values='rating',
)

# %%
dfs['pivot'].head()
# Out:
# title   'burbs, The (1989)  10 Things I Hate About You (1999)  \
# userId
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
# 5                      NaN                                NaN
#
# title   101 Dalmatians (1961)  101 Dalmatians (1996)  12 Angry Men (1957)  \
# userId
# 1                         NaN                    NaN                  NaN
# 2                         NaN                    NaN                  NaN
# 3                         NaN                    NaN                  NaN
# 4                         NaN                    NaN                  NaN
# 5                         NaN                    NaN                  NaN
#
# title   13th Warrior, The (1999)  2 Days in the Valley (1996)  \
# userId
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# 5                            NaN                          NaN
#
# title   20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# userId
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 5                                       NaN                           NaN
#
# title   2010 (1984)  ...  Year of Living Dangerously (1982)  \
# userId               ...
# 1               NaN  ...                                NaN
# 2               NaN  ...                                NaN
# 3               NaN  ...                                NaN
# 4               NaN  ...                                NaN
# 5               NaN  ...                                NaN
#
# title   Yellow Submarine (1968)  Yojimbo (1961)  You've Got Mail (1998)  \
# userId
# 1                           NaN             NaN                     NaN
# 2                           NaN             4.0                     NaN
# 3                           NaN             NaN                     NaN
# 4                           NaN             NaN                     NaN
# 5                           NaN             NaN                     NaN
#
# title   Young Frankenstein (1974)  Young Guns (1988)  Young Guns II (1990)  \
# userId
# 1                             NaN                NaN                   NaN
# 2                             NaN                NaN                   NaN
# 3                             NaN                5.0                   4.0
# 4                             NaN                NaN                   NaN
# 5                             NaN                NaN                   NaN
#
# title   Young Sherlock Holmes (1985)  Zero Effect (1998)  eXistenZ (1999)
# userId
# 1                                NaN                 NaN              NaN
# 2                                NaN                 NaN              NaN
# 3                                NaN                 NaN              NaN
# 4                                NaN                 NaN              NaN
# 5                                NaN                 NaN              NaN
#
# [5 rows x 1426 columns]

# %%
# %%time
corr = dfs['pivot'].corr(min_periods=THRESHOLD)
# Out:
# Wall time: 8.21 s

# %%
corr.head()
# Out:
# title                              'burbs, The (1989)  \
# title
# 'burbs, The (1989)                           1.000000
# 101 Dalmatians (1961)              ...                           0.566591
# 101 Dalmatians (1996)              ...                           0.472273
# 12 Angry Men (1957)                ...                           0.617534
#
# title                              Yellow Submarine (1968)  Yojimbo (1961)  \
# title
# 'burbs, The (1989)                                0.594924        0.408946
# 10 Things I Hate About You (1999)                 0.526471        0.663689
# 101 Dalmatians (1961)                             0.497710        0.652566
# 101 Dalmatians (1996)                             0.505308        0.493127
# 12 Angry Men (1957)                               0.537366        0.661270
#
# title                              You've Got Mail (1998)  \
# title
# 'burbs, The (1989)                               0.649142
# 10 Things I Hate About You (1999)                0.597452
# 101 Dalmatians (1961)                            0.590143
# 101 Dalmatians (1996)                            0.660958
# 12 Angry Men (1957)                              0.565703
#
# title                              Young Frankenstein (1974)  \
# title
# 'burbs, The (1989)                                  0.520692
# 10 Things I Hate About You (1999)                   0.558381
# 101 Dalmatians (1961)                               0.624611
# 101 Dalmatians (1996)                               0.568876
# 12 Angry Men (1957)                                 0.624835
#
# title                              Young Guns (1988)  Young Guns II (1990)  \
# title
# 'burbs, The (1989)                          0.688144              0.728074
# 10 Things I Hate About You (1999)           0.660736              0.600116
# 101 Dalmatians (1961)                       0.643006              0.633519
# 101 Dalmatians (1996)                       0.614987              0.587062
# 12 Angry Men (1957)                         0.500000              0.514702
#
# title                              Young Sherlock Holmes (1985)  \
# title
# 'burbs, The (1989)                                     0.639212
# 10 Things I Hate About You (1999)                      0.592877
# 101 Dalmatians (1961)                                  0.506952
# 101 Dalmatians (1996)                                  0.529752
# 12 Angry Men (1957)                                    0.640564
#
# title                              Zero Effect (1998)  eXistenZ (1999)
# title
# 'burbs, The (1989)                           0.519752         0.567586
# 10 Things I Hate About You (1999)            0.599654         0.511183
# 101 Dalmatians (1961)                        0.601416         0.483782
# 101 Dalmatians (1996)                        0.535942         0.548348
# 12 Angry Men (1957)                          0.607138         0.659245
#
# [5 rows x 1426 columns]

# %%
rows = dfs['test'].to_numpy()

# %%
def get_harmonic(W, X):
    den = 0
    for (w, x) in zip(W, X):
        den += (w/x)
    num = sum(W)
    res = num/den
    
    return res

# %%
def get_true_positive(Y, k):
    return [1 if y >= k else 0 for y in Y]

# %%
def get_f1(y_true, y_pred, k=3):
    y_true = get_true_positive(y_true, k)
    y_pred = get_true_positive(y_pred, k)
    
    return f1_score(y_true, y_pred)

# %%
# %%time
predictions = []
for row in rows[:]:
    u = row[2]
    m = row[0]
    r = row[1]
    movies_sim = corr[m].dropna()
    movies_sim = movies_sim[movies_sim.values >= SIMILARITY]
    tot = 0
    rating = 0
    W = []
    X = []
    #print(u, m, r)
    #print(movies_sim)
    for n, s in zip(movies_sim.index, movies_sim.values):
        rate = dfs['pivot'][n].loc[u]
        if rate != rate:
            continue
        tot += 1
        X.append(rate)
        W.append(s)
        if tot >= NEIGHBOR:
            break
    if tot > 0:
        rating = get_harmonic(W, X)
    else:
        rating = dfs['pivot'].loc[u].dropna()
        #print(rating)
        rating = sum(rating.values)/rating.shape[0]
    predictions.append(rating)
# Out:
# Wall time: 47.9 s

# %%
dfs['test']['prediction'] = predictions

# %%
mean_absolute_percentage_error(dfs['test']['rating'], dfs['test']['prediction'])
# Out:
# 0.29596744418989407

# %%
get_f1(dfs['test']['rating'], dfs['test']['prediction'])
# Out:
# 0.863791857383763
